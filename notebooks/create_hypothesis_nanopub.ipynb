# %% [markdown]
# # Create Hypothesis Nanopublications (Super-Pattern)
#
# This notebook generates **hypothesis nanopublications** using the super-pattern template.
#
# The super-pattern expresses formal hypotheses as: *In the context of [context], [subject] [qualifier] [relation] [object]*
#
# **Template:** [Expressing a general hypothesis with a super-pattern](http://purl.org/np/RABf4z3vjQrAOkGQRHvW82MrZTqtAsGWU7C9W1niaMOPw)
#
# **Reference:** [Kuhn et al. (2021) - Semantic micro-contributions with decentralized nanopublication services](https://doi.org/10.1145/3460210.3493561)

# %% [markdown]
# ---
# ## Configuration

# %%
# Path to your hypothesis config file
CONFIG_FILE = "../config/dggs_hypothesis.json"
CONFIG_FILE = "/Users/annef/Documents/ScienceLive/ai-agent/DGGS-AI-nanopubs/dggs_hypothesis_fixed.json"
CONFIG_FILE = "../biodiversity/RIO_article_121887/lifewatch_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/androcymbium/androcymbium_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/arvanitidis/arvanitidis_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/arvanitidis2024/arvanitidis2024_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/crete/crete_declaration_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/dimuri2022/dimuri2022_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/dimuri2023/dimuri2023_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/heraklion/heraklion_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/pclarkii/pclarkii_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/souza2025/souza2025_hypothesis_corrected.json"
OUTPUT_DIR = "../output/biodiversity/"

# %% [markdown]
# ---
# ## Setup

# %%
import json
import sys
from pathlib import Path
from datetime import datetime, timezone

# Add parent directory to path for imports
sys.path.insert(0, str(Path('.').resolve().parent))

try:
    from nanopub_utils import load_config, get_timestamp, escape_literal
    print("✓ Loaded nanopub_utils")
except ImportError:
    print("⚠ nanopub_utils not found, using inline functions")
    
    def load_config(path):
        with open(path, 'r', encoding='utf-8') as f:
            return json.load(f)
    
    def get_timestamp():
        return datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%S.%f")[:-3] + "Z"
    
    def escape_literal(text):
        return text.replace('\\', '\\\\').replace('"', '\\"').replace('\n', '\\n').replace('\r', '\\r')

# Output directory
OUTPUT_DIR = Path(OUTPUT_DIR)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"✓ Output directory: {OUTPUT_DIR}")
# Out:
# ✓ Loaded nanopub_utils
# ✓ Output directory: ../output/biodiversity

# %% [markdown]
# ---
# ## Load Configuration

# %%
config = load_config(CONFIG_FILE)

metadata = config['metadata']
nanopubs = config['nanopublications']

print(f"✓ Loaded configuration")
print(f"  Source paper: {metadata['source_paper']['title'][:60]}...")
print(f"  Creator: {metadata['creator_name']}")
print(f"  Hypotheses to create: {len(nanopubs)}")
print()
for np_config in nanopubs:
    print(f"  - {np_config['id']}: {np_config['label'][:60]}...")
# Out:
# ✓ Loaded configuration
#   Source paper: Fragmented Networks: Challenges in communication and cohesio...
#   Creator: Anne Fouilloux
#   Hypotheses to create: 4
#
#   - hyp_fragmentation_impedes_collaboration: Communication fragmentation impedes collaboration efficiency...
#   - hyp_shared_standards_increases_interoperability: Shared data standards increase interoperability between BioR...
#   - hyp_inperson_increases_responsiveness: In-person meetings increase communication responsiveness...
#   - hyp_dedicated_channels_increases_internal_collab: Dedicated communication channels increase internal collabora...

# %% [markdown]
# ---
# ## Template URIs

# %%
# Hypothesis super-pattern template
HYPOTHESIS_TEMPLATE = "http://purl.org/np/RABf4z3vjQrAOkGQRHvW82MrZTqtAsGWU7C9W1niaMOPw"

# Standard templates
PROVENANCE_TEMPLATE = "http://purl.org/np/RANwQa4ICWS5SOjw7gp99nBpXBasapwtZF1fIM3H2gYTM"
PUBINFO_TEMPLATE_1 = "http://purl.org/np/RAA2MfqdBCzmz9yVWjKLXNbyfBNcwsMmOqcNUxkk1maIM"
PUBINFO_TEMPLATE_2 = "http://purl.org/np/RAh1gm83JiG5M6kDxXhaYT1l49nCzyrckMvTzcPn-iv90"
PUBINFO_TEMPLATE_3 = "http://purl.org/np/RAjpBMlw3owYhJUBo3DtsuDlXsNAJ8cnGeWAutDVjuAuI"

# Super-pattern namespace
SP = "https://w3id.org/linkflows/superpattern/terms/"

print("✓ Template URIs configured")
# Out:
# ✓ Template URIs configured

# %% [markdown]
# ---
# ## Generate Nanopublications

# %%
def generate_hypothesis_trig(np_config, metadata):
    """Generate a hypothesis nanopublication using the super-pattern template.
    
    Super-pattern structure:
    - Context Class: The domain where the hypothesis applies
    - Subject Class: What type of thing is the subject
    - Relation: The relationship type
    - Object Class: What type of thing is the object  
    - Qualifier (optional): Frequency qualifier
    """
    
    creator_orcid = metadata['creator_orcid']
    creator_name = metadata['creator_name']
    
    label = escape_literal(np_config['label'])
    context_class = np_config['context_class']
    subject_class = np_config['subject_class']
    relation = np_config['relation']
    object_class = np_config['object_class']
    qualifier = np_config.get('qualifier')  # Optional
    
    timestamp = get_timestamp()
    
    trig = f'''@prefix this: <http://purl.org/nanopub/temp/np/> .
@prefix sub: <http://purl.org/nanopub/temp/np#> .
@prefix np: <http://www.nanopub.org/nschema#> .
@prefix dct: <http://purl.org/dc/terms/> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix prov: <http://www.w3.org/ns/prov#> .
@prefix orcid: <https://orcid.org/> .
@prefix nt: <https://w3id.org/np/o/ntemplate/> .
@prefix npx: <http://purl.org/nanopub/x/> .
@prefix sp: <https://w3id.org/linkflows/superpattern/terms/> .
@prefix foaf: <http://xmlns.com/foaf/0.1/> .

sub:Head {{
  this: a np:Nanopublication ;
    np:hasAssertion sub:assertion ;
    np:hasProvenance sub:provenance ;
    np:hasPublicationInfo sub:pubinfo .
}}

sub:assertion {{
  sub:spi a sp:SuperPatternInstance ;
    rdfs:label "{label}" ;
    sp:hasContextClass <{context_class['uri']}> ;
    sp:hasSubjectClass <{subject_class['uri']}> ;
    sp:hasRelation <{relation['uri']}> ;
    sp:hasObjectClass <{object_class['uri']}>
'''
    
    # Add qualifier if provided
    if qualifier:
        trig += f'''    ; sp:hasQualifier <{qualifier['uri']}>
'''
    
    trig += '''    .
}

'''
    
    # Provenance
    trig += f'''sub:provenance {{
  sub:assertion prov:wasAttributedTo orcid:{creator_orcid} .
}}

sub:pubinfo {{
  this: dct:created "{timestamp}"^^xsd:dateTime ;
    dct:creator orcid:{creator_orcid} ;
    dct:license <https://creativecommons.org/licenses/by/4.0/> ;
    npx:introduces sub:spi ;
    npx:wasCreatedAt <https://sciencelive4all.org/> ;
    nt:wasCreatedFromProvenanceTemplate <{PROVENANCE_TEMPLATE}> ;
    nt:wasCreatedFromPubinfoTemplate <{PUBINFO_TEMPLATE_1}> , <{PUBINFO_TEMPLATE_2}> , <{PUBINFO_TEMPLATE_3}> ;
    nt:wasCreatedFromTemplate <{HYPOTHESIS_TEMPLATE}> .

  orcid:{creator_orcid} foaf:name "{creator_name}" .
'''
    
    # Add labels for classes (for display in Nanodash)
    trig += f'''
  <{context_class['uri']}> rdfs:label "{escape_literal(context_class['label'])}" .
  <{subject_class['uri']}> rdfs:label "{escape_literal(subject_class['label'])}" .
  <{object_class['uri']}> rdfs:label "{escape_literal(object_class['label'])}" .
'''
    
    trig += '''}
'''
    
    return trig

print("✓ Generation function defined")
# Out:
# ✓ Generation function defined

# %%
# Generate all nanopublications
generated_files = []

for np_config in nanopubs:
    np_id = np_config['id']
    trig_content = generate_hypothesis_trig(np_config, metadata)
    
    output_file = OUTPUT_DIR / f"{np_id}.trig"
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(trig_content)
    
    generated_files.append(output_file)
    print(f"✓ Generated: {output_file.name}")
    print(f"    {np_config['label'][:70]}...")

print(f"\n✓ Generated {len(generated_files)} hypothesis nanopublication(s)")
# Out:
# ✓ Generated: hyp_fragmentation_impedes_collaboration.trig
#     Communication fragmentation impedes collaboration efficiency...
# ✓ Generated: hyp_shared_standards_increases_interoperability.trig
#     Shared data standards increase interoperability between BioRIs...
# ✓ Generated: hyp_inperson_increases_responsiveness.trig
#     In-person meetings increase communication responsiveness...
# ✓ Generated: hyp_dedicated_channels_increases_internal_collab.trig
#     Dedicated communication channels increase internal collaboration inten...
#
# ✓ Generated 4 hypothesis nanopublication(s)

# %% [markdown]
# ---
# ## Preview Generated Content

# %%
# Preview the first generated file
if generated_files:
    print(f"Preview of {generated_files[0].name}:")
    print("=" * 70)
    with open(generated_files[0], 'r') as f:
        print(f.read())
# Out:
# Preview of hyp_fragmentation_impedes_collaboration.trig:
# ======================================================================
# @prefix this: <http://purl.org/nanopub/temp/np/> .
# @prefix sub: <http://purl.org/nanopub/temp/np#> .
# @prefix np: <http://www.nanopub.org/nschema#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix orcid: <https://orcid.org/> .
# @prefix nt: <https://w3id.org/np/o/ntemplate/> .
# @prefix npx: <http://purl.org/nanopub/x/> .
# @prefix sp: <https://w3id.org/linkflows/superpattern/terms/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
#
# sub:Head {
#   this: a np:Nanopublication ;
#     np:hasAssertion sub:assertion ;
#     np:hasProvenance sub:provenance ;
#     np:hasPublicationInfo sub:pubinfo .
# }
#
# sub:assertion {
#   sub:spi a sp:SuperPatternInstance ;
#     rdfs:label "Communication fragmentation impedes collaboration efficiency" ;
#     sp:hasContextClass <http://www.wikidata.org/entity/Q46> ;
#     sp:hasSubjectClass <https://www.wikidata.org/wiki/Q1205196> ;
#     sp:hasRelation <https://w3id.org/linkflows/superpattern/terms/causes> ;
#     sp:hasObjectClass <https://www.wikidata.org/wiki/Q115098150>
#     ; sp:hasQualifier <https://w3id.org/linkflows/superpattern/terms/generallyQualifier>
#     .
# }
#
# sub:provenance {
#   sub:assertion prov:wasAttributedTo orcid:0000-0002-1784-2920 .
# }
#
# sub:pubinfo {
#   this: dct:created "2026-02-01T15:58:45.397Z"^^xsd:dateTime ;
#     dct:creator orcid:0000-0002-1784-2920 ;
#     dct:license <https://creativecommons.org/licenses/by/4.0/> ;
#     npx:introduces sub:spi ;
#     npx:wasCreatedAt <https://sciencelive4all.org/> ;
#     nt:wasCreatedFromProvenanceTemplate <http://purl.org/np/RANwQa4ICWS5SOjw7gp99nBpXBasapwtZF1fIM3H2gYTM> ;
#     nt:wasCreatedFromPubinfoTemplate <http://purl.org/np/RAA2MfqdBCzmz9yVWjKLXNbyfBNcwsMmOqcNUxkk1maIM> , <http://purl.org/np/RAh1gm83JiG5M6kDxXhaYT1l49nCzyrckMvTzcPn-iv90> , <http://purl.org/np/RAjpBMlw3owYhJUBo3DtsuDlXsNAJ8cnGeWAutDVjuAuI> ;
#     nt:wasCreatedFromTemplate <http://purl.org/np/RABf4z3vjQrAOkGQRHvW82MrZTqtAsGWU7C9W1niaMOPw> .
#
#   orcid:0000-0002-1784-2920 foaf:name "Anne Fouilloux" .
#
#   <http://www.wikidata.org/entity/Q46> rdfs:label "Europe" .
#   <https://www.wikidata.org/wiki/Q1205196> rdfs:label "intercultural communication" .
#   <https://www.wikidata.org/wiki/Q115098150> rdfs:label "inefficiency" .
# }

# %% [markdown]
# ---
# ## Summary

# %%
print("=" * 70)
print("SUMMARY")
print("=" * 70)
print(f"Config file:  {CONFIG_FILE}")
print(f"Output dir:   {OUTPUT_DIR}")
print(f"Generated:    {len(generated_files)} file(s)")
print()
print("Hypotheses:")
for np_config in nanopubs:
    qual = np_config.get('qualifier', {}).get('label', 'no qualifier')
    print(f"  [{np_config['id']}]")
    print(f"    Context: {np_config['context_class']['label']}")
    print(f"    Subject: {np_config['subject_class']['label']}")
    print(f"    Relation: {np_config['relation']['label']} ({qual})")
    print(f"    Object: {np_config['object_class']['label']}")
    print()
print("Next steps:")
print("  1. Review the generated .trig files")
print("  2. Sign: nanopub sign <filename>.trig")
print("  3. Publish: nanopub publish <filename>.signed.trig")
# Out:
# ======================================================================
# SUMMARY
# ======================================================================
# Config file:  ../biodiversity/souza2025/souza2025_hypothesis_corrected.json
# Output dir:   ../output/biodiversity
# Generated:    4 file(s)
#
# Hypotheses:
#   [hyp_fragmentation_impedes_collaboration]
#     Context: Europe
#     Subject: intercultural communication
#     Relation: causes (generally (≥90% of cases))
#     Object: inefficiency
#
#   [hyp_shared_standards_increases_interoperability]
#     Context: research infrastructure
#     Subject: data standardization
#     Relation: increases (generally (≥90% of cases))
#     Object: data interoperability standard
#
#   [hyp_inperson_increases_responsiveness]
#     Context: research infrastructure
#     Subject: Face-to-face interaction
#     Relation: increases (generally (≥90% of cases))
#     Object: responsiveness
#
#   [hyp_dedicated_channels_increases_internal_collab]
#     Context: research infrastructure
#     Subject: Information-bearer channel
#     Relation: increases (frequently (≥50%))
#     Object: collaboration
#
# Next steps:
#   1. Review the generated .trig files
#   2. Sign: nanopub sign <filename>.trig
#   3. Publish: nanopub publish <filename>.signed.trig

# %%
PUBLISH = True  # Set to True when ready to publish
USE_TEST_SERVER = False  # Set to False for production
PROFILE_PATH = "/Users/annef/Documents/ScienceLive/ai-profile/profile.yml"  # Set to your profile.yml path

if PUBLISH:
    from nanopub import Nanopub, NanopubConf, load_profile
    
    profile = load_profile(PROFILE_PATH)
    print(f"Loaded profile: {profile.name}")
    
    conf = NanopubConf(profile=profile, use_test_server=USE_TEST_SERVER)

    print("generated_files: ", generated_files)
    for trig_file in generated_files:
        np_obj = Nanopub(rdf=trig_file, conf=conf)
        np_obj.sign()
        
        signed_path = trig_file.with_suffix('.signed.trig')
        np_obj.store(signed_path)
        print(f"✓ Signed: {signed_path}")
        
        np_obj.publish()
        print(f"✓ Published: {np_obj.source_uri}")
else:
    print("Publishing disabled. Set PUBLISH = True to enable.")
    print("\nManual signing:")
    for f in generated_files:
        print(f"  nanopub sign {f}")
# Out:
# Loaded profile: claude-ai-agent
# generated_files:  [PosixPath('../output/biodiversity/hyp_fragmentation_impedes_collaboration.trig'), PosixPath('../output/biodiversity/hyp_shared_standards_increases_interoperability.trig'), PosixPath('../output/biodiversity/hyp_inperson_increases_responsiveness.trig'), PosixPath('../output/biodiversity/hyp_dedicated_channels_increases_internal_collab.trig')]
# ✓ Signed: ../output/biodiversity/hyp_fragmentation_impedes_collaboration.signed.trig
# ✓ Published: https://w3id.org/np/RA8J1KmM136suks8F5EHSyxC_tp6DUQwjhdkOsStAk8m4
# ✓ Signed: ../output/biodiversity/hyp_shared_standards_increases_interoperability.signed.trig
# ✓ Published: https://w3id.org/np/RAVYkNBhkup3U1pGr3_HybuLR6sW99RmjD81tquUW1-1A
# ✓ Signed: ../output/biodiversity/hyp_inperson_increases_responsiveness.signed.trig
# ✓ Published: https://w3id.org/np/RAxc5_8auXtqY4ncZ_NM9zTBRcibMmNyJ9pP2wiD5Ikso
# ✓ Signed: ../output/biodiversity/hyp_dedicated_channels_increases_internal_collab.signed.trig
# ✓ Published: https://w3id.org/np/RAoyQBV1TfGImHOKnXi6VO2EpZbck0yEFamVrcwWxWktk

# %% [markdown]
# ---
# ## JSON Configuration Template
#
# ```json
# {
#   "metadata": {
#     "source_paper": {
#       "title": "Your Paper Title",
#       "doi": "10.xxxx/xxxxx"
#     },
#     "creator_orcid": "0000-0002-XXXX-XXXX",
#     "creator_name": "Your Name",
#     "is_part_of": {
#       "uri": null,
#       "label": null
#     }
#   },
#   "nanopublications": [
#     {
#       "id": "hypothesis_unique_id",
#       "label": "Human-readable hypothesis statement",
#       "context_class": {
#         "uri": "http://www.wikidata.org/entity/QXXX",
#         "label": "Context domain"
#       },
#       "subject_class": {
#         "uri": "http://www.wikidata.org/entity/QXXX",
#         "label": "Subject type"
#       },
#       "relation": {
#         "uri": "https://w3id.org/linkflows/superpattern/terms/causes",
#         "label": "causes"
#       },
#       "object_class": {
#         "uri": "http://www.wikidata.org/entity/QXXX",
#         "label": "Object type"
#       },
#       "qualifier": {
#         "uri": "https://w3id.org/linkflows/superpattern/terms/generallyQualifier",
#         "label": "generally (≥90% of cases)"
#       },
#       "note": "Optional note about the hypothesis"
#     }
#   ]
# }
# ```
#
# ### Available Relations
#
# | Relation | URI | Meaning |
# |----------|-----|--------|
# | affects | `sp:affects` | Positively or negatively affects |
# | causes | `sp:causes` | Causes existence of |
# | contributesTo | `sp:contributesTo` | Positively affects |
# | inhibits | `sp:inhibits` | Negatively affects |
# | enables | `sp:enables` | Causes activity to happen |
# | prevents | `sp:prevents` | Causes activity not to happen |
# | increases | `sp:increases` | Causes value to increase |
# | decreases | `sp:decreases` | Causes value to decrease |
# | requires | `sp:requires` | Would not exist without |
# | hasLargerValueThan | `sp:hasLargerValueThan` | Quantitative comparison |
# | hasSmallerValueThan | `sp:hasSmallerValueThan` | Quantitative comparison |
# | hasSameValueAs | `sp:hasSameValueAs` | Equality |
# | cooccursWith | `sp:cooccursWith` | Spatiotemporal proximity |
# | follows | `sp:follows` | Temporal sequence |
# | includes | `sp:includes` | Spatiotemporal inclusion |
#
# ### Available Qualifiers
#
# | Qualifier | URI | Meaning |
# |-----------|-----|--------|
# | always | `sp:alwaysQualifier` | 100% of cases |
# | generally | `sp:generallyQualifier` | ≥90% of cases |
# | mostly | `sp:mostlyQualifier` | ≥50% of cases |
# | frequently | `sp:frequentlyQualifier` | ≥10% of cases |
# | sometimes | `sp:sometimesQualifier` | ≥0.1% of cases |
# | never | `sp:neverQualifier` | 0% of cases |
#
# ### Special Context
#
# Use `https://w3id.org/linkflows/superpattern/terms/UniversalContext` when no specific context applies.

# %% [markdown]
# # Create Hypothesis Nanopublications (Super-Pattern)
#
# This notebook generates **hypothesis nanopublications** using the super-pattern template.
#
# The super-pattern expresses formal hypotheses as: *In the context of [context], [subject] [qualifier] [relation] [object]*
#
# **Template:** [Expressing a general hypothesis with a super-pattern](http://purl.org/np/RABf4z3vjQrAOkGQRHvW82MrZTqtAsGWU7C9W1niaMOPw)
#
# **Reference:** [Kuhn et al. (2021) - Semantic micro-contributions with decentralized nanopublication services](https://doi.org/10.1145/3460210.3493561)

# %% [markdown]
# ---
# ## Configuration

# %%
# Path to your hypothesis config file
CONFIG_FILE = "../config/dggs_hypothesis.json"
CONFIG_FILE = "/Users/annef/Documents/ScienceLive/ai-agent/DGGS-AI-nanopubs/dggs_hypothesis_fixed.json"
CONFIG_FILE = "../biodiversity/RIO_article_121887/lifewatch_hypothesis_corrected.json"
CONFIG_FILE = "../biodiversity/androcymbium/androcymbium_hypothesis_corrected.json"
OUTPUT_DIR = "../output/biodiversity/"

# %% [markdown]
# ---
# ## Setup

# %%
import json
import sys
from pathlib import Path
from datetime import datetime, timezone

# Add parent directory to path for imports
sys.path.insert(0, str(Path('.').resolve().parent))

try:
    from nanopub_utils import load_config, get_timestamp, escape_literal
    print("✓ Loaded nanopub_utils")
except ImportError:
    print("⚠ nanopub_utils not found, using inline functions")
    
    def load_config(path):
        with open(path, 'r', encoding='utf-8') as f:
            return json.load(f)
    
    def get_timestamp():
        return datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%S.%f")[:-3] + "Z"
    
    def escape_literal(text):
        return text.replace('\\', '\\\\').replace('"', '\\"').replace('\n', '\\n').replace('\r', '\\r')

# Output directory
OUTPUT_DIR = Path(OUTPUT_DIR)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"✓ Output directory: {OUTPUT_DIR}")
# Out:
# ✓ Loaded nanopub_utils
# ✓ Output directory: ../output/biodiversity

# %% [markdown]
# ---
# ## Load Configuration

# %%
config = load_config(CONFIG_FILE)

metadata = config['metadata']
nanopubs = config['nanopublications']

print(f"✓ Loaded configuration")
print(f"  Source paper: {metadata['source_paper']['title'][:60]}...")
print(f"  Creator: {metadata['creator_name']}")
print(f"  Hypotheses to create: {len(nanopubs)}")
print()
for np_config in nanopubs:
    print(f"  - {np_config['id']}: {np_config['label'][:60]}...")
# Out:
# ✓ Loaded configuration
#   Source paper: Monitoring data on the effect of domestic livestock and rabb...
#   Creator: Antonio Jesús Pérez-Luque
#   Hypotheses to create: 4
#
#   - hyp_herbivory_positive: Small herbivores positively affect Colchicaceae population d...
#   - hyp_rainfall_phenology: Rainfall patterns affect Androcymbium europaeum vegetative d...
#   - hyp_landuse_habitat_loss: Land use transformation causes habitat deterioration for A. ...
#   - hyp_population_fluctuation: Climatic conditions cause population size fluctuations in A....

# %% [markdown]
# ---
# ## Template URIs

# %%
# Hypothesis super-pattern template
HYPOTHESIS_TEMPLATE = "http://purl.org/np/RABf4z3vjQrAOkGQRHvW82MrZTqtAsGWU7C9W1niaMOPw"

# Standard templates
PROVENANCE_TEMPLATE = "http://purl.org/np/RANwQa4ICWS5SOjw7gp99nBpXBasapwtZF1fIM3H2gYTM"
PUBINFO_TEMPLATE_1 = "http://purl.org/np/RAA2MfqdBCzmz9yVWjKLXNbyfBNcwsMmOqcNUxkk1maIM"
PUBINFO_TEMPLATE_2 = "http://purl.org/np/RAh1gm83JiG5M6kDxXhaYT1l49nCzyrckMvTzcPn-iv90"
PUBINFO_TEMPLATE_3 = "http://purl.org/np/RAjpBMlw3owYhJUBo3DtsuDlXsNAJ8cnGeWAutDVjuAuI"

# Super-pattern namespace
SP = "https://w3id.org/linkflows/superpattern/terms/"

print("✓ Template URIs configured")
# Out:
# ✓ Template URIs configured

# %% [markdown]
# ---
# ## Generate Nanopublications

# %%
def generate_hypothesis_trig(np_config, metadata):
    """Generate a hypothesis nanopublication using the super-pattern template.
    
    Super-pattern structure:
    - Context Class: The domain where the hypothesis applies
    - Subject Class: What type of thing is the subject
    - Relation: The relationship type
    - Object Class: What type of thing is the object  
    - Qualifier (optional): Frequency qualifier
    """
    
    creator_orcid = metadata['creator_orcid']
    creator_name = metadata['creator_name']
    
    label = escape_literal(np_config['label'])
    context_class = np_config['context_class']
    subject_class = np_config['subject_class']
    relation = np_config['relation']
    object_class = np_config['object_class']
    qualifier = np_config.get('qualifier')  # Optional
    
    timestamp = get_timestamp()
    
    trig = f'''@prefix this: <http://purl.org/nanopub/temp/np/> .
@prefix sub: <http://purl.org/nanopub/temp/np#> .
@prefix np: <http://www.nanopub.org/nschema#> .
@prefix dct: <http://purl.org/dc/terms/> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix prov: <http://www.w3.org/ns/prov#> .
@prefix orcid: <https://orcid.org/> .
@prefix nt: <https://w3id.org/np/o/ntemplate/> .
@prefix npx: <http://purl.org/nanopub/x/> .
@prefix sp: <https://w3id.org/linkflows/superpattern/terms/> .
@prefix foaf: <http://xmlns.com/foaf/0.1/> .

sub:Head {{
  this: a np:Nanopublication ;
    np:hasAssertion sub:assertion ;
    np:hasProvenance sub:provenance ;
    np:hasPublicationInfo sub:pubinfo .
}}

sub:assertion {{
  sub:spi a sp:SuperPatternInstance ;
    rdfs:label "{label}" ;
    sp:hasContextClass <{context_class['uri']}> ;
    sp:hasSubjectClass <{subject_class['uri']}> ;
    sp:hasRelation <{relation['uri']}> ;
    sp:hasObjectClass <{object_class['uri']}>
'''
    
    # Add qualifier if provided
    if qualifier:
        trig += f'''    ; sp:hasQualifier <{qualifier['uri']}>
'''
    
    trig += '''    .
}

'''
    
    # Provenance
    trig += f'''sub:provenance {{
  sub:assertion prov:wasAttributedTo orcid:{creator_orcid} .
}}

sub:pubinfo {{
  this: dct:created "{timestamp}"^^xsd:dateTime ;
    dct:creator orcid:{creator_orcid} ;
    dct:license <https://creativecommons.org/licenses/by/4.0/> ;
    npx:introduces sub:spi ;
    npx:wasCreatedAt <https://sciencelive4all.org/> ;
    nt:wasCreatedFromProvenanceTemplate <{PROVENANCE_TEMPLATE}> ;
    nt:wasCreatedFromPubinfoTemplate <{PUBINFO_TEMPLATE_1}> , <{PUBINFO_TEMPLATE_2}> , <{PUBINFO_TEMPLATE_3}> ;
    nt:wasCreatedFromTemplate <{HYPOTHESIS_TEMPLATE}> .

  orcid:{creator_orcid} foaf:name "{creator_name}" .
'''
    
    # Add labels for classes (for display in Nanodash)
    trig += f'''
  <{context_class['uri']}> rdfs:label "{escape_literal(context_class['label'])}" .
  <{subject_class['uri']}> rdfs:label "{escape_literal(subject_class['label'])}" .
  <{object_class['uri']}> rdfs:label "{escape_literal(object_class['label'])}" .
'''
    
    trig += '''}
'''
    
    return trig

print("✓ Generation function defined")
# Out:
# ✓ Generation function defined

# %%
# Generate all nanopublications
generated_files = []

for np_config in nanopubs:
    np_id = np_config['id']
    trig_content = generate_hypothesis_trig(np_config, metadata)
    
    output_file = OUTPUT_DIR / f"{np_id}.trig"
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(trig_content)
    
    generated_files.append(output_file)
    print(f"✓ Generated: {output_file.name}")
    print(f"    {np_config['label'][:70]}...")

print(f"\n✓ Generated {len(generated_files)} hypothesis nanopublication(s)")
# Out:
# ✓ Generated: hyp_herbivory_positive.trig
#     Small herbivores positively affect Colchicaceae population density...
# ✓ Generated: hyp_rainfall_phenology.trig
#     Rainfall patterns affect Androcymbium europaeum vegetative development...
# ✓ Generated: hyp_landuse_habitat_loss.trig
#     Land use transformation causes habitat deterioration for A. europaeum...
# ✓ Generated: hyp_population_fluctuation.trig
#     Climatic conditions cause population size fluctuations in A. europaeum...
#
# ✓ Generated 4 hypothesis nanopublication(s)

# %% [markdown]
# ---
# ## Preview Generated Content

# %%
# Preview the first generated file
if generated_files:
    print(f"Preview of {generated_files[0].name}:")
    print("=" * 70)
    with open(generated_files[0], 'r') as f:
        print(f.read())
# Out:
# Preview of hyp_herbivory_positive.trig:
# ======================================================================
# @prefix this: <http://purl.org/nanopub/temp/np/> .
# @prefix sub: <http://purl.org/nanopub/temp/np#> .
# @prefix np: <http://www.nanopub.org/nschema#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix orcid: <https://orcid.org/> .
# @prefix nt: <https://w3id.org/np/o/ntemplate/> .
# @prefix npx: <http://purl.org/nanopub/x/> .
# @prefix sp: <https://w3id.org/linkflows/superpattern/terms/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
#
# sub:Head {
#   this: a np:Nanopublication ;
#     np:hasAssertion sub:assertion ;
#     np:hasProvenance sub:provenance ;
#     np:hasPublicationInfo sub:pubinfo .
# }
#
# sub:assertion {
#   sub:spi a sp:SuperPatternInstance ;
#     rdfs:label "Small herbivores positively affect Colchicaceae population density" ;
#     sp:hasContextClass <https://www.wikidata.org/wiki/Q304888> ;
#     sp:hasSubjectClass <https://www.wikidata.org/wiki/Q45874067> ;
#     sp:hasRelation <https://w3id.org/linkflows/superpattern/terms/increases> ;
#     sp:hasObjectClass <https://www.wikidata.org/wiki/Q186181>
#     ; sp:hasQualifier <https://w3id.org/linkflows/superpattern/terms/frequentlyQualifier>
#     .
# }
#
# sub:provenance {
#   sub:assertion prov:wasAttributedTo orcid:0000-0002-1747-0469 .
# }
#
# sub:pubinfo {
#   this: dct:created "2026-01-30T21:17:58.982Z"^^xsd:dateTime ;
#     dct:creator orcid:0000-0002-1747-0469 ;
#     dct:license <https://creativecommons.org/licenses/by/4.0/> ;
#     npx:introduces sub:spi ;
#     npx:wasCreatedAt <https://sciencelive4all.org/> ;
#     nt:wasCreatedFromProvenanceTemplate <http://purl.org/np/RANwQa4ICWS5SOjw7gp99nBpXBasapwtZF1fIM3H2gYTM> ;
#     nt:wasCreatedFromPubinfoTemplate <http://purl.org/np/RAA2MfqdBCzmz9yVWjKLXNbyfBNcwsMmOqcNUxkk1maIM> , <http://purl.org/np/RAh1gm83JiG5M6kDxXhaYT1l49nCzyrckMvTzcPn-iv90> , <http://purl.org/np/RAjpBMlw3owYhJUBo3DtsuDlXsNAJ8cnGeWAutDVjuAuI> ;
#     nt:wasCreatedFromTemplate <http://purl.org/np/RABf4z3vjQrAOkGQRHvW82MrZTqtAsGWU7C9W1niaMOPw> .
#
#   orcid:0000-0002-1747-0469 foaf:name "Antonio Jesús Pérez-Luque" .
#
#   <https://www.wikidata.org/wiki/Q304888> rdfs:label "mediterranean climate ecosystem in Southern Europe" .
#   <https://www.wikidata.org/wiki/Q45874067> rdfs:label "herbivory" .
#   <https://www.wikidata.org/wiki/Q186181> rdfs:label "Colchicaceae" .
# }

# %% [markdown]
# ---
# ## Summary

# %%
print("=" * 70)
print("SUMMARY")
print("=" * 70)
print(f"Config file:  {CONFIG_FILE}")
print(f"Output dir:   {OUTPUT_DIR}")
print(f"Generated:    {len(generated_files)} file(s)")
print()
print("Hypotheses:")
for np_config in nanopubs:
    qual = np_config.get('qualifier', {}).get('label', 'no qualifier')
    print(f"  [{np_config['id']}]")
    print(f"    Context: {np_config['context_class']['label']}")
    print(f"    Subject: {np_config['subject_class']['label']}")
    print(f"    Relation: {np_config['relation']['label']} ({qual})")
    print(f"    Object: {np_config['object_class']['label']}")
    print()
print("Next steps:")
print("  1. Review the generated .trig files")
print("  2. Sign: nanopub sign <filename>.trig")
print("  3. Publish: nanopub publish <filename>.signed.trig")
# Out:
# ======================================================================
# SUMMARY
# ======================================================================
# Config file:  ../biodiversity/androcymbium/androcymbium_hypothesis_corrected.json
# Output dir:   ../output/biodiversity
# Generated:    4 file(s)
#
# Hypotheses:
#   [hyp_herbivory_positive]
#     Context: mediterranean climate ecosystem in Southern Europe
#     Subject: herbivory
#     Relation: increases (frequently (≥50% of cases))
#     Object: Colchicaceae
#
#   [hyp_rainfall_phenology]
#     Context: semi-arid climate
#     Subject: Precipitation patterns alter growth of temperate vegetation
#     Relation: affects (generally (≥90% of cases))
#     Object: Androcymbium europaeum
#
#   [hyp_landuse_habitat_loss]
#     Context: Almería Province
#     Subject: land use
#     Relation: causes (generally (≥90% of cases))
#     Object: Habitat Deterioration, Habitat Destruction, and Metapopulation Persistence in a Heterogenous Landscape
#
#   [hyp_population_fluctuation]
#     Context: Iberian Peninsula
#     Subject: climatic conditions of storage
#     Relation: causes (generally (≥90% of cases))
#     Object: population fluctuations
#
# Next steps:
#   1. Review the generated .trig files
#   2. Sign: nanopub sign <filename>.trig
#   3. Publish: nanopub publish <filename>.signed.trig

# %%
PUBLISH = True  # Set to True when ready to publish
USE_TEST_SERVER = False  # Set to False for production
PROFILE_PATH = "/Users/annef/Documents/ScienceLive/ai-profile/profile.yml"  # Set to your profile.yml path

if PUBLISH:
    from nanopub import Nanopub, NanopubConf, load_profile
    
    profile = load_profile(PROFILE_PATH)
    print(f"Loaded profile: {profile.name}")
    
    conf = NanopubConf(profile=profile, use_test_server=USE_TEST_SERVER)

    print("generated_files: ", generated_files)
    for trig_file in generated_files:
        np_obj = Nanopub(rdf=trig_file, conf=conf)
        np_obj.sign()
        
        signed_path = trig_file.with_suffix('.signed.trig')
        np_obj.store(signed_path)
        print(f"✓ Signed: {signed_path}")
        
        np_obj.publish()
        print(f"✓ Published: {np_obj.source_uri}")
else:
    print("Publishing disabled. Set PUBLISH = True to enable.")
    print("\nManual signing:")
    for f in generated_files:
        print(f"  nanopub sign {f}")
# Out:
# Loaded profile: claude-ai-agent
# generated_files:  [PosixPath('../output/biodiversity/hyp_herbivory_positive.trig'), PosixPath('../output/biodiversity/hyp_rainfall_phenology.trig'), PosixPath('../output/biodiversity/hyp_landuse_habitat_loss.trig'), PosixPath('../output/biodiversity/hyp_population_fluctuation.trig')]
# ✓ Signed: ../output/biodiversity/hyp_herbivory_positive.signed.trig
# ✓ Published: https://w3id.org/np/RAAwVvJzCLOVzLgaMqukkuobkhHeZk-26pmO5aLbzzgIE
# ✓ Signed: ../output/biodiversity/hyp_rainfall_phenology.signed.trig
# ✓ Published: https://w3id.org/np/RAqFU67ACdRPlh_aZJG2fu0FaeFFuYgRjQ2ozQHjJ5xrk
# ✓ Signed: ../output/biodiversity/hyp_landuse_habitat_loss.signed.trig
# ✓ Published: https://w3id.org/np/RATVIThZTgoe9Nwu32MvN8TNnUkVpII-dmvtauIMK39HM
# ✓ Signed: ../output/biodiversity/hyp_population_fluctuation.signed.trig
# ✓ Published: https://w3id.org/np/RAg39GKGk2YPKrZFwDu_0h8RxpVwiDYBC7n3FdlRUvxxU

# %% [markdown]
# ---
# ## JSON Configuration Template
#
# ```json
# {
#   "metadata": {
#     "source_paper": {
#       "title": "Your Paper Title",
#       "doi": "10.xxxx/xxxxx"
#     },
#     "creator_orcid": "0000-0002-XXXX-XXXX",
#     "creator_name": "Your Name",
#     "is_part_of": {
#       "uri": null,
#       "label": null
#     }
#   },
#   "nanopublications": [
#     {
#       "id": "hypothesis_unique_id",
#       "label": "Human-readable hypothesis statement",
#       "context_class": {
#         "uri": "http://www.wikidata.org/entity/QXXX",
#         "label": "Context domain"
#       },
#       "subject_class": {
#         "uri": "http://www.wikidata.org/entity/QXXX",
#         "label": "Subject type"
#       },
#       "relation": {
#         "uri": "https://w3id.org/linkflows/superpattern/terms/causes",
#         "label": "causes"
#       },
#       "object_class": {
#         "uri": "http://www.wikidata.org/entity/QXXX",
#         "label": "Object type"
#       },
#       "qualifier": {
#         "uri": "https://w3id.org/linkflows/superpattern/terms/generallyQualifier",
#         "label": "generally (≥90% of cases)"
#       },
#       "note": "Optional note about the hypothesis"
#     }
#   ]
# }
# ```
#
# ### Available Relations
#
# | Relation | URI | Meaning |
# |----------|-----|--------|
# | affects | `sp:affects` | Positively or negatively affects |
# | causes | `sp:causes` | Causes existence of |
# | contributesTo | `sp:contributesTo` | Positively affects |
# | inhibits | `sp:inhibits` | Negatively affects |
# | enables | `sp:enables` | Causes activity to happen |
# | prevents | `sp:prevents` | Causes activity not to happen |
# | increases | `sp:increases` | Causes value to increase |
# | decreases | `sp:decreases` | Causes value to decrease |
# | requires | `sp:requires` | Would not exist without |
# | hasLargerValueThan | `sp:hasLargerValueThan` | Quantitative comparison |
# | hasSmallerValueThan | `sp:hasSmallerValueThan` | Quantitative comparison |
# | hasSameValueAs | `sp:hasSameValueAs` | Equality |
# | cooccursWith | `sp:cooccursWith` | Spatiotemporal proximity |
# | follows | `sp:follows` | Temporal sequence |
# | includes | `sp:includes` | Spatiotemporal inclusion |
#
# ### Available Qualifiers
#
# | Qualifier | URI | Meaning |
# |-----------|-----|--------|
# | always | `sp:alwaysQualifier` | 100% of cases |
# | generally | `sp:generallyQualifier` | ≥90% of cases |
# | mostly | `sp:mostlyQualifier` | ≥50% of cases |
# | frequently | `sp:frequentlyQualifier` | ≥10% of cases |
# | sometimes | `sp:sometimesQualifier` | ≥0.1% of cases |
# | never | `sp:neverQualifier` | 0% of cases |
#
# ### Special Context
#
# Use `https://w3id.org/linkflows/superpattern/terms/UniversalContext` when no specific context applies.
